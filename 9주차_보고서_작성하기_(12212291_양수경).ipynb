# %% [markdown]
# <a href="https://colab.research.google.com/github/sooox89/kswcodingtest/blob/main/9%EC%A3%BC%EC%B0%A8_%EB%B3%B4%EA%B3%A0%EC%84%9C_%EC%9E%91%EC%84%B1%ED%95%98%EA%B8%B0_(12212291_%EC%96%91%EC%88%98%EA%B2%BD).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###보고서 작성하기 (12212291 양수경)

# %%
a = [10,20,30]
print(a)
# Out:
# [10, 20, 30]

# %%
b = []
print(b)
# Out:
# []

# %%
c = list(range(1,10))
print(c)

# %%
a = [[10,20,30],[40,50,60],[90,100,110]]
print(a)
print(a[1][1])
# Out:
# [[10, 20, 30], [40, 50, 60], [90, 100, 110]]
# 50

# %%
a =[4,11,53,30]
print(len(a))
a.append(9)
a.insert(2,10) # a 리스트의 2번 인덱스에 10 삽입
a.remove(9) # a 리스트에 저장된 9 삭제
a.sort()  # a 리스트 오름차순으로 정렬
a.reverse() # a 리스트 역순으로 정렬
print(a)
# Out:
# 4
# [53, 30, 11, 10, 4]

# %% [markdown]
# ###### 요즘 양수경의 주된 관심거리는 카페 창업에 있다. 커피 전문점 사이에서 경쟁력을 갖추려면 어떻게 해야 해야할지 걱정이 많았다.OO는 카페 창업을 하는 사람들을 위한 체크리스트가 생각났다.
#  - 체크리스트
#
# > 비슷한 업종의 유명한 맛집을 직접 방문 했는가?
#
# > 우리 가게만의 시그너처 메뉴를 연구했는가?
#
# > 카페를 열 장소에서 오가는 사람들의 유동 패턴과 특징을 충분히 파악 했는가?
#
# > 메뉴의 단가를 결정하기 위해 합리적인 원가 산출법을 적용하는가?

# %%
# 양수경이 조사한 일주일간 유동인구 데이터(월-일)를 리스트에 저장하기
# 데이터 : 232, 258, 232, 221, 270, 81, 47

a = [232, 258, 232, 221, 270, 81, 47]
print("A = ",a)
n =len(a)
print(n)
# Out:
# A =  [232, 258, 232, 221, 270, 81, 47]
# 7

# %%
my_sum = 0
for i in range(0,n):
  my_sum +=a[i]
print('Total sum :', my_sum )
# Out:
# Total sum : 1341

# %%
my_avg = 0
my_avg = my_sum/n
print('Total average = ', my_avg)
# Out:
# Total average =  191.57142857142858

# %%
import matplotlib.pyplot as plt
x_data = ['MON','TUE', 'WED', 'THR', 'FRI', 'SAT', 'SUN']
plt.title('Floating Population Data(1week)', fontsize = 18)
plt.xlabel("Day of the week", fontsize=12)
plt.ylabel("Floating Population", fontsize=12)
plt.scatter(x_data,a) #산점도 그리기
plt.plot(x_data, a, 'bo-')   #라인 그래프 그리기
plt.show()

# %%
weekday_size = 5
weekday_sum = 0
weekday_avg = 0

for i in range(0, weekday_size):
 weekday_sum+=a[i] 

weekday_avg = weekday_sum/weekday_size
print("weekday Data : ",a[0:5])
print("weekday Sum :", weekday_sum)
print("weekday Average : ", weekday_avg)
# Out:
# weekday Data :  [232, 258, 232, 221, 270]
# weekday Sum : 1213
# weekday Average :  242.6

# %%
import matplotlib.pyplot as plt

plt.title('Floating Population Data(1week)' ,fontsize=16)
plt.xlabel("Day of the week", fontsize=12)
plt.ylabel("Floating Population", fontsize=12)
plt.plot(x_data,a)
plt.scatter(x_data[0:weekday_size], a[0:weekday_size], c='red', s =50)
